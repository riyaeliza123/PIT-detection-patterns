# %%
import pandas as pd

# %%
detection_counts = pd.read_csv("data/most_detected_tags.csv")
dwell_loc = pd.read_csv("data/loc_code_detection_patterns.csv")
dwell_antenna = pd.read_csv("data/antenna_detection_patterns.csv")
location = pd.read_csv("data/location_lat_long.csv")

# %%
detection_counts
# Out:
#           tag_id   count in_cleaning_table
# 0     989.001042  273253                no
# 1     989.001039  111089                no
# 2     989.001042   89789                no
# 3     989.001040   82246                no
# 4     989.001039   78683                no
# ...          ...     ...               ...
# 6781  989.001045       1                no
# 6782  989.001041       1                no
# 6783  989.001042       1                no
# 6784  989.001041       1                no
# 6785  989.001045       1                no
#
# [6786 rows x 3 columns]

# %%
dwell_loc
# Out:
#            tag_id loc_code  start_date    end_date              dwell_time  \
# 0      989.001007       7A  2020-09-26  2020-09-26  0 days 00:02:05.290000
# 1      989.001033       21  2020-09-27  2020-09-27         0 days 00:00:00
# 2      989.001007       22  2020-10-03  2020-10-03         0 days 00:00:00
# 3      989.001007      232  2020-10-23  2020-10-23  0 days 00:03:49.320000
# 4      989.001007      231  2020-10-23  2020-10-23  0 days 00:06:36.940000
# ...           ...      ...         ...         ...                     ...
# 36754  989.001043       44  2025-01-06  2025-01-06  0 days 04:53:32.120000
# 36755  989.001043       45  2025-01-06  2025-01-07  0 days 14:40:47.490000
# 36756  989.001043       44  2025-01-07  2025-01-07  0 days 09:10:03.680000
# 36757  989.001043       45  2025-01-07  2025-01-08  0 days 14:35:53.630000
# 36758  989.001043       44  2025-01-08  2025-01-09  0 days 23:59:15.950000
#
#        number_of_detections
# 0                         3
# 1                         1
# 2                         2
# 3                         2
# 4                         2
# ...                     ...
# 36754                     3
# 36755                     3
# 36756                     2
# 36757                     3
# 36758                     8
#
# [36759 rows x 6 columns]

# %% [markdown]
# # Summaries

# %% [markdown]
# ## For an individual tag

# %%
tag = 989.001038870418

print("Tag ID is:", tag)
print("Total number of detections:", detection_counts[detection_counts["tag_id"] == tag]["count"].iloc[0])
print("Found in cleaning table? ", detection_counts[detection_counts["tag_id"] == tag]["in_cleaning_table"].iloc[0])
print("Details of each detection:")
dwell_loc[dwell_loc.tag_id == tag]
# Out:
# Tag ID is: 989.001038870418
# Total number of detections: 57
# Found in cleaning table?  no
# Details of each detection:
#           tag_id loc_code  start_date    end_date              dwell_time  \
# 7     989.001039       84  2021-04-29  2021-04-29  0 days 09:40:46.170000
# 11    989.001039       83  2021-04-29  2021-04-29         0 days 00:00:00
# 12    989.001039       84  2021-04-29  2021-04-29         0 days 00:00:00
# 1180  989.001039       83  2021-10-16  2021-10-16  0 days 01:34:37.090000
# 1191  989.001039       84  2021-10-16  2021-10-16         0 days 00:00:00
#
#       number_of_detections
# 7                       45
# 11                       1
# 12                       3
# 1180                     6
# 1191                     2

# %% [markdown]
# 1. Now connect lat and long to each loc code and plot movement.
# 2. use upstream/downstream data also
